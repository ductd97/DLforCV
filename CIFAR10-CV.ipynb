# %%
# %matplotlib inline
import torch
import matplotlib.pyplot as plt
import torchvision
import torchvision.transforms as transforms
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time

# %%
torch.cuda.empty_cache()

# %%
batch_size_train = 128
# learning_rate = 0.01
num_workers = 2
pin_memory = True
random_seed = 42

criterion = nn.CrossEntropyLoss()
early_stop = 20


momentum = 0.9
nesterov = True
weight_decay = 5e-4

# %%
transform = transforms.Compose(
    [
     transforms.ToTensor(),
    ]
)

# %%
trainset = torchvision.datasets.CIFAR10(root='./cifar-data', train=True, download=True, transform=transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./cifar-data/cifar-10-python.tar.gz to ./cifar-data

# %%
testset = torchvision.datasets.CIFAR10(root='./cifar-data', train=False, download=True, transform=transform)
# Out:
# Files already downloaded and verified

# %%
def nomarllization(dataset):
  mean = np.mean(dataset.data, axis=(0,1,2))/255
  std  = np.mean(dataset.data, axis=(0,1,2))/255
  return transforms.Normalize(mean=mean, std=std)

# %%
train_transf = transforms.Compose(
    [
     transforms.Resize((40, 40)),     
     transforms.RandomCrop((32, 32)),  
     transforms.RandomHorizontalFlip(),
     transforms.RandomRotation(15),
     transforms.ToTensor(),
     nomarllization(trainset)
    ]
)

# %%
test_transf = transforms.Compose(
    [
     transforms.ToTensor(),
     nomarllization(testset)
    ]
)

# %%
trainset = torchvision.datasets.CIFAR10(root='./cifar-data', train=True, download=True, transform=train_transf)
# Out:
# Files already downloaded and verified

# %%
validset = torchvision.datasets.CIFAR10(root='./cifar-data', train=True, download=True, transform=train_transf)
# Out:
# Files already downloaded and verified

# %%
testset = torchvision.datasets.CIFAR10(root='./cifar-data', train=False, download=True, transform=test_transf)
# Out:
# Files already downloaded and verified

# %%
classes = trainset.class_to_idx

# %%
trainset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./cifar-data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(40, 40), interpolation=PIL.Image.BILINEAR)
#                RandomCrop(size=(32, 32), padding=None)
#                RandomHorizontalFlip(p=0.5)
#                RandomRotation(degrees=[-15.0, 15.0], resample=False, expand=False)
#                ToTensor()
#                Normalize(mean=[0.49139968 0.48215841 0.44653091], std=[0.49139968 0.48215841 0.44653091])
#            )

# %%
num_train = len(trainset)
indices = list(range(num_train))
split = int(np.floor(num_train*0.8/5))

np.random.seed(random_seed)
np.random.shuffle(indices)

train_idx, val_idx = indices[split:], indices[:split]

train_sampler = torch.utils.data.sampler.SubsetRandomSampler(train_idx)
valid_sampler = torch.utils.data.sampler.SubsetRandomSampler(val_idx)

trainloader = torch.utils.data.DataLoader(
    trainset, 
    batch_size=batch_size_train, 
    sampler=train_sampler, 
    num_workers=num_workers, 
    pin_memory = pin_memory)

validloader = torch.utils.data.DataLoader(
    trainset, 
    batch_size=batch_size_train, 
    sampler=valid_sampler, 
    num_workers=num_workers, 
    pin_memory = pin_memory)

# %%
split
# Out:
# 8000

# %%
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size_train, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)

# %%
# X_train, X_validate, y_train, y_validate = train_test_split(trainloader.dataset.data, trainloader.dataset.targets, train_size=0.7, random_state=random_seed)

# %%
 train, validate = torch.utils.data.random_split(
    trainset,
    [num_train-split, split])
 trainloader = torch.utils.data.DataLoader(
     train, 
     batch_size=batch_size_train, 
     shuffle=True,
     num_workers=num_workers,
     pin_memory=pin_memory
     )
 validloader = torch.utils.data.DataLoader(
     validate,
     batch_size=batch_size_train, 
     shuffle=True,
     num_workers=num_workers,
     pin_memory=pin_memory
     )

# %%
n_cols = 10
n_rows = 10
n      = n_cols * n_rows

# %%
train_images = [trainloader.dataset.dataset.data[i] for i in train_idx]
train_labels = [trainloader.dataset.dataset.targets[i] for i in train_idx]

validate_labels = [validloader.dataset.dataset.targets[i] for i in val_idx]
test_labels = testloader.dataset.targets

# %%
def show_img_per_class():
  fig, ax = plt. subplots(n_rows, n_cols + 1, figsize=(15,15))
  fig.tight_layout(pad=0.3)
  for _, (k,v) in enumerate(classes.items()):
    random_sample = np.random.choice([i for i, c in enumerate(train_labels) if c == v], n_rows)
    ax[v, 0].text(0.5, 0.5, k, fontsize=15, fontweight='bold', color='white')
    ax[v, 0].axis("off")
    for idx, imidx in enumerate(random_sample):
      ax[v, idx+1].imshow(train_images[imidx])
      ax[v, idx+1].axis("off")
  plt.show()

# %%
# show_img_per_class()

# %%
# # bins = np.arange(0, 10.5) - 0.5
# # plt.hist(trainloader.dataset.targets, density=True, bins=bins,edgecolor='k')
# # plt.xticks(bins + 0.5)

stat =  pd.DataFrame({'Label': np.array(train_labels), 'Set_type':'train'})
stat = stat.append(pd.DataFrame({'Label': np.array(validate_labels), 'Set_type':'validate'}),ignore_index=True)
stat = stat.append(pd.DataFrame({'Label': test_labels,'Set_type':'test'}),ignore_index=True)

# %%
plt.figure(figsize=(20,10))
# sns.countplot(x='Label',hue='Set_type',data=stat)

# %%
class Net(nn.Module):
    def __init__(self):
      super(Net, self).__init__()
      self.conv_layer = nn.Sequential(
        # Conv Layer block 1
        nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
        nn.BatchNorm2d(32),
        nn.ReLU(inplace=True),
        nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
        nn.ReLU(inplace=True),
        nn.MaxPool2d(kernel_size=2, stride=2),

        # Conv Layer block 2
        nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
        nn.BatchNorm2d(128),
        nn.ReLU(inplace=True),
        nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
        nn.ReLU(inplace=True),
        nn.MaxPool2d(kernel_size=2, stride=2),
        nn.Dropout2d(p=0.05),

        # Conv Layer block 3
        nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
        nn.BatchNorm2d(256),
        nn.ReLU(inplace=True),
        nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
        nn.ReLU(inplace=True),
        nn.MaxPool2d(kernel_size=2, stride=2),
      )

      self.fc_layer = nn.Sequential(
        nn.Dropout(p=0.1),
        nn.Linear(4096, 1024),
        nn.ReLU(inplace=True),
        nn.Linear(1024, 512),
        nn.ReLU(inplace=True),
        nn.Dropout(p=0.1),
        nn.Linear(512, 10)
      )
    def forward(self, x):
      # conv layers
      x = self.conv_layer(x)    
      # flatten
      x = x.view(x.size(0), -1)    
      # fc layer
      x = self.fc_layer(x)
      return x

# %%
def train(network, device):
  # epoch_start_time = time.time()
  running_loss = 0
  accuracy = 0
  network.train()
  for batch_idx, (data, target) in enumerate(trainloader):
    data, target = data.to(device), target.to(device)
    optimizer.zero_grad()
    output = network(data)
    # loss = F.nll_loss(F.log_softmax(output), target)
    loss = criterion(output,target)
    loss.backward()
    optimizer.step()
  print("Number of batches: ", ite)
  print("Accurary average over batches: ", accuracy)
  print("Loss average over batches    : ",running_loss)
    # if batch_idx == 1:
    #   network.eval()
    #   pout = network(data)
    #   pred = torch.argmax(pout, dim=1)
    #   print("pred  : ",pred)
    #   print("target: ",target)
    #   print((pred==target).sum())
    #   wrong_pred = data[pred!=target].cpu()
    #   wrong_id = (pred!=target.view_as(pred)).nonzero()[:,0]
    #   print("wrong_id: ", wrong_id)
    #   print("wrong pred size: ",wrong_pred.shape)
    #   fig = plt.figure()
    #   for i,v in enumerate(wrong_id):
    #     print("Id wrong: ", v)
    #     ax = fig.add_subplot(2,5,i+1)
    #     ax.imshow(torch.squeeze(data[v].cpu()).numpy())
    #     ax.axis('off')
    #     ax.set_title(
    #         (
    #             target[v].cpu().item(), 
    #             pred[v].cpu().item()
    #         )
    #         )
    #   break
      # print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
        # epoch, batch_idx * len(data), len(trainloader.dataset),
        # 100. * batch_idx / len(trainloader), loss.item()))
      # train_losses.append(loss.item())
      # train_counter.append(
        # (batch_idx*64) + ((epoch-1)*len(trainloader.dataset)))
      # torch.save(network.state_dict(), './results/model.pth')
      # torch.save(optimizer.state_dict(), './results/optimizer.pth')

# %%
def calculate_loss_accuracy(network, dataloader, mode=""):
  running_loss = 0
  correct = 0
  number_of_data = 0

  device = torch.device('cuda' if torch.cuda.is_available else 'cpu')
  network = network.to(device)
  
  network.eval()
  with torch.no_grad():
    for batch_idx, (data, target) in enumerate(dataloader):
      data, target = data.to(device), target.to(device)
      output = network(data)
      pred = torch.argmax(output, dim=1)
      correct += (pred==target).sum().item()

      loss = criterion(output, target)
      running_loss += loss.item()
      number_of_data += len(data)

      if mode == 'test':
        wrong_id = (pred!=target.view_as(pred)).nonzero()[:,0]
        fig = plt.figure(figsize=(10,10))
        for i,v in enumerate(wrong_id):
          ax = fig.add_subplot(2,10,i+1)
          ax.imshow(torch.squeeze(data[v].cpu()).numpy())
          ax.axis('off')
          ax.set_title((
                target[v].cpu().item(), 
                pred[v].cpu().item()
          ))
        fig.tight_layout()
    accuracy = correct/number_of_data
    loss = running_loss/len(dataloader)
    print("Number of batches: ", len(dataloader))
    print("Correct: {} On {} - Accuracy: {:.4f}".format(correct, number_of_data,accuracy))
    print("Loss over whole dataset: {:.4f}".format(loss))
  return accuracy, loss

# %%
def fit(network, trainloader, validateloader, opts):

  learning_rate, momentum, weight_decay, n_epochs = opts['learning_rate'], opts['momentum'], opts['weight_decay'], opts['n_epochs']

  # best_val_loss = float('Inf')
  best_val_accuracy = 0
  counter = 0

  # criterion = nn.CrossEntropyLoss()
  device = torch.device('cuda' if torch.cuda.is_available else 'cpu')
  network = network.to(device)

  for epoch in range(1, n_epochs + 1):
    if epoch%50 == 0:
      learning_rate /=10
    learning_rates.append(learning_rate)

    optimizer = optim.SGD(network.parameters(), lr = learning_rate, momentum=momentum, weight_decay=weight_decay, nesterov=True)

    epoch_start_time = time.time()
    network.train()

    train_accuracy, train_loss = 0, 0

    # epoch_start_time = time.time()
    for batch_idx, (data, target) in enumerate(trainloader):
      data, target = data.to(device), target.to(device)
      optimizer.zero_grad()
      output = network(data)
      loss = criterion(output, target)
      
      pred = torch.argmax(output, dim=1)
      train_loss += loss.item()
      train_accuracy += (pred==target).sum().item()

      loss.backward()
      optimizer.step()

    epoch_times.append(time.time() - epoch_start_time)
    #evaluate per epoch
    val_accuracy, val_loss = calculate_loss_accuracy(network, validateloader)
    # train_accuracy, train_loss = calculate_loss_accuracy(network, device, trainloader)
    train_accuracy /= 42000
    train_loss /= len(trainloader)
    print("==========================================================================================================================")
    print("Epoch {}/{} - Train accuracy: {:.4f} - Train loss: {:.4f} - Validate accuracy: {:.4f} - Validate loss: {:.4f}".format(
        epoch, n_epochs, train_accuracy, train_loss, val_accuracy, val_loss
    ))
    print("==========================================================================================================================")
    train_losses.append(train_loss)
    train_acces.append(train_accuracy)
    val_losses.append(val_loss)
    val_acces.append(val_accuracy)

    #Save best network
    # if val_losses[-1] < best_val_loss:
      # best_val_loss = val_losses[-1]
    if val_acces[-1] > best_val_accuracy:
      best_val_accuracy = val_acces[-1]
      counter = 0
      torch.save(network.state_dict(),'checkpoint.pth')
    else:
      counter += 1
      print("***************************************************************************")
      # print('Validation loss has not improved from: {:.4f} - Count: {}'.format(best_val_loss, counter))
      print('Validation accuracy has not improved from: {:.4f} - Count: {}'.format(best_val_accuracy, counter))
      print("***************************************************************************")
      # if counter > early_stop:
      print("Early Stopping!")
  network.load_state_dict(torch.load('checkpoint.pth'))
        # break

# %%
def predict(network, dataloader):
  return 1

# %%
network = Net()

# optimizer = optim.SGD(network.parameters(), lr = learning_rate)
# device = torch.device('cuda' if torch.cuda.is_available else 'cpu')
# network = network.to(device)

# test(device)
# for epoch in range(1, n_epochs + 1):
#   train(network,device)
#   check(network,device)

opts = {
    "n_epochs": 300,
    "learning_rate": 0.1,
    "momentum": 0.9,
    "weight_decay": 5e-4
}

train_losses, train_acces = [], []
val_losses, val_acces = [], []
epoch_times = []
learning_rates = []
fit(network, trainloader, validloader, opts)
# Out:
# Number of batches:  63
# Correct: 3052 On 8000 - Accuracy: 0.3815
# Loss over whole dataset: 1.7425
# ==========================================================================================================================
# Epoch 1/300 - Train accuracy: 0.3641 - Train loss: 1.7094 - Validate accuracy: 0.3815 - Validate loss: 1.7425
# ==========================================================================================================================
# Number of batches:  63
# Correct: 4070 On 8000 - Accuracy: 0.5088
# Loss over whole dataset: 1.5054
# ==========================================================================================================================
# Epoch 2/300 - Train accuracy: 0.5116 - Train loss: 1.3678 - Validate accuracy: 0.5088 - Validate loss: 1.5054
# ==========================================================================================================================
# Number of batches:  63
# Correct: 2997 On 8000 - Accuracy: 0.3746
# Loss over whole dataset: 2.2218
# ==========================================================================================================================
# Epoch 3/300 - Train accuracy: 0.5813 - Train loss: 1.1857 - Validate accuracy: 0.3746 - Validate loss: 2.2218
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.5088 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 4645 On 8000 - Accuracy: 0.5806
# Loss over whole dataset: 1.1842
# ==========================================================================================================================
# Epoch 4/300 - Train accuracy: 0.6310 - Train loss: 1.0536 - Validate accuracy: 0.5806 - Validate loss: 1.1842
# ==========================================================================================================================
# Number of batches:  63
# Correct: 4626 On 8000 - Accuracy: 0.5783
# Loss over whole dataset: 1.2562
# ==========================================================================================================================
# Epoch 5/300 - Train accuracy: 0.6636 - Train loss: 0.9713 - Validate accuracy: 0.5783 - Validate loss: 1.2562
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.5806 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 4764 On 8000 - Accuracy: 0.5955
# Loss over whole dataset: 1.2087
# ==========================================================================================================================
# Epoch 6/300 - Train accuracy: 0.6843 - Train loss: 0.9120 - Validate accuracy: 0.5955 - Validate loss: 1.2087
# ==========================================================================================================================
# Number of batches:  63
# Correct: 5063 On 8000 - Accuracy: 0.6329
# Loss over whole dataset: 1.0747
# ==========================================================================================================================
# Epoch 7/300 - Train accuracy: 0.6973 - Train loss: 0.8714 - Validate accuracy: 0.6329 - Validate loss: 1.0747
# ==========================================================================================================================
# Number of batches:  63
# Correct: 4839 On 8000 - Accuracy: 0.6049
# Loss over whole dataset: 1.1735
# ==========================================================================================================================
# Epoch 8/300 - Train accuracy: 0.7120 - Train loss: 0.8314 - Validate accuracy: 0.6049 - Validate loss: 1.1735
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.6329 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 4036 On 8000 - Accuracy: 0.5045
# Loss over whole dataset: 1.4867
# ==========================================================================================================================
# Epoch 9/300 - Train accuracy: 0.7201 - Train loss: 0.8085 - Validate accuracy: 0.5045 - Validate loss: 1.4867
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.6329 - Count: 2
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5577 On 8000 - Accuracy: 0.6971
# Loss over whole dataset: 0.9012
# ==========================================================================================================================
# Epoch 10/300 - Train accuracy: 0.7291 - Train loss: 0.7863 - Validate accuracy: 0.6971 - Validate loss: 0.9012
# ==========================================================================================================================
# Number of batches:  63
# Correct: 4948 On 8000 - Accuracy: 0.6185
# Loss over whole dataset: 1.1769
# ==========================================================================================================================
# Epoch 11/300 - Train accuracy: 0.7332 - Train loss: 0.7665 - Validate accuracy: 0.6185 - Validate loss: 1.1769
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.6971 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5007 On 8000 - Accuracy: 0.6259
# Loss over whole dataset: 1.1586
# ==========================================================================================================================
# Epoch 12/300 - Train accuracy: 0.7392 - Train loss: 0.7495 - Validate accuracy: 0.6259 - Validate loss: 1.1586
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.6971 - Count: 2
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5138 On 8000 - Accuracy: 0.6422
# Loss over whole dataset: 1.0815
# ==========================================================================================================================
# Epoch 13/300 - Train accuracy: 0.7466 - Train loss: 0.7372 - Validate accuracy: 0.6422 - Validate loss: 1.0815
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.6971 - Count: 3
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5491 On 8000 - Accuracy: 0.6864
# Loss over whole dataset: 0.8983
# ==========================================================================================================================
# Epoch 14/300 - Train accuracy: 0.7543 - Train loss: 0.7221 - Validate accuracy: 0.6864 - Validate loss: 0.8983
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.6971 - Count: 4
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5229 On 8000 - Accuracy: 0.6536
# Loss over whole dataset: 1.0319
# ==========================================================================================================================
# Epoch 15/300 - Train accuracy: 0.7569 - Train loss: 0.7043 - Validate accuracy: 0.6536 - Validate loss: 1.0319
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.6971 - Count: 5
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5355 On 8000 - Accuracy: 0.6694
# Loss over whole dataset: 0.9843
# ==========================================================================================================================
# Epoch 16/300 - Train accuracy: 0.7607 - Train loss: 0.6937 - Validate accuracy: 0.6694 - Validate loss: 0.9843
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.6971 - Count: 6
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5354 On 8000 - Accuracy: 0.6693
# Loss over whole dataset: 0.9846
# ==========================================================================================================================
# Epoch 17/300 - Train accuracy: 0.7626 - Train loss: 0.6897 - Validate accuracy: 0.6693 - Validate loss: 0.9846
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.6971 - Count: 7
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5429 On 8000 - Accuracy: 0.6786
# Loss over whole dataset: 0.9577
# ==========================================================================================================================
# Epoch 18/300 - Train accuracy: 0.7675 - Train loss: 0.6809 - Validate accuracy: 0.6786 - Validate loss: 0.9577
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.6971 - Count: 8
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 4840 On 8000 - Accuracy: 0.6050
# Loss over whole dataset: 1.3679
# ==========================================================================================================================
# Epoch 19/300 - Train accuracy: 0.7689 - Train loss: 0.6742 - Validate accuracy: 0.6050 - Validate loss: 1.3679
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.6971 - Count: 9
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5871 On 8000 - Accuracy: 0.7339
# Loss over whole dataset: 0.7784
# ==========================================================================================================================
# Epoch 20/300 - Train accuracy: 0.7691 - Train loss: 0.6696 - Validate accuracy: 0.7339 - Validate loss: 0.7784
# ==========================================================================================================================
# Number of batches:  63
# Correct: 4986 On 8000 - Accuracy: 0.6232
# Loss over whole dataset: 1.1688
# ==========================================================================================================================
# Epoch 21/300 - Train accuracy: 0.7737 - Train loss: 0.6570 - Validate accuracy: 0.6232 - Validate loss: 1.1688
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5237 On 8000 - Accuracy: 0.6546
# Loss over whole dataset: 1.0852
# ==========================================================================================================================
# Epoch 22/300 - Train accuracy: 0.7769 - Train loss: 0.6554 - Validate accuracy: 0.6546 - Validate loss: 1.0852
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 2
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5600 On 8000 - Accuracy: 0.7000
# Loss over whole dataset: 0.9133
# ==========================================================================================================================
# Epoch 23/300 - Train accuracy: 0.7776 - Train loss: 0.6500 - Validate accuracy: 0.7000 - Validate loss: 0.9133
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 3
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5444 On 8000 - Accuracy: 0.6805
# Loss over whole dataset: 0.9561
# ==========================================================================================================================
# Epoch 24/300 - Train accuracy: 0.7802 - Train loss: 0.6442 - Validate accuracy: 0.6805 - Validate loss: 0.9561
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 4
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5871 On 8000 - Accuracy: 0.7339
# Loss over whole dataset: 0.8076
# ==========================================================================================================================
# Epoch 25/300 - Train accuracy: 0.7774 - Train loss: 0.6404 - Validate accuracy: 0.7339 - Validate loss: 0.8076
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 5
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5501 On 8000 - Accuracy: 0.6876
# Loss over whole dataset: 0.9754
# ==========================================================================================================================
# Epoch 26/300 - Train accuracy: 0.7822 - Train loss: 0.6329 - Validate accuracy: 0.6876 - Validate loss: 0.9754
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 6
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 4946 On 8000 - Accuracy: 0.6182
# Loss over whole dataset: 1.2050
# ==========================================================================================================================
# Epoch 27/300 - Train accuracy: 0.7830 - Train loss: 0.6322 - Validate accuracy: 0.6182 - Validate loss: 1.2050
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 7
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5636 On 8000 - Accuracy: 0.7045
# Loss over whole dataset: 0.8935
# ==========================================================================================================================
# Epoch 28/300 - Train accuracy: 0.7866 - Train loss: 0.6217 - Validate accuracy: 0.7045 - Validate loss: 0.8935
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 8
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5590 On 8000 - Accuracy: 0.6987
# Loss over whole dataset: 0.9060
# ==========================================================================================================================
# Epoch 29/300 - Train accuracy: 0.7854 - Train loss: 0.6195 - Validate accuracy: 0.6987 - Validate loss: 0.9060
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 9
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 4914 On 8000 - Accuracy: 0.6142
# Loss over whole dataset: 1.2102
# ==========================================================================================================================
# Epoch 30/300 - Train accuracy: 0.7868 - Train loss: 0.6231 - Validate accuracy: 0.6142 - Validate loss: 1.2102
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 10
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5814 On 8000 - Accuracy: 0.7268
# Loss over whole dataset: 0.8177
# ==========================================================================================================================
# Epoch 31/300 - Train accuracy: 0.7896 - Train loss: 0.6164 - Validate accuracy: 0.7268 - Validate loss: 0.8177
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 11
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 4582 On 8000 - Accuracy: 0.5727
# Loss over whole dataset: 1.5052
# ==========================================================================================================================
# Epoch 32/300 - Train accuracy: 0.7889 - Train loss: 0.6164 - Validate accuracy: 0.5727 - Validate loss: 1.5052
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 12
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5156 On 8000 - Accuracy: 0.6445
# Loss over whole dataset: 1.2787
# ==========================================================================================================================
# Epoch 33/300 - Train accuracy: 0.7894 - Train loss: 0.6196 - Validate accuracy: 0.6445 - Validate loss: 1.2787
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 13
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5776 On 8000 - Accuracy: 0.7220
# Loss over whole dataset: 0.7950
# ==========================================================================================================================
# Epoch 34/300 - Train accuracy: 0.7908 - Train loss: 0.6132 - Validate accuracy: 0.7220 - Validate loss: 0.7950
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 14
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5248 On 8000 - Accuracy: 0.6560
# Loss over whole dataset: 1.0778
# ==========================================================================================================================
# Epoch 35/300 - Train accuracy: 0.7928 - Train loss: 0.6047 - Validate accuracy: 0.6560 - Validate loss: 1.0778
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 15
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5530 On 8000 - Accuracy: 0.6913
# Loss over whole dataset: 0.9450
# ==========================================================================================================================
# Epoch 36/300 - Train accuracy: 0.7973 - Train loss: 0.5983 - Validate accuracy: 0.6913 - Validate loss: 0.9450
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 16
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5421 On 8000 - Accuracy: 0.6776
# Loss over whole dataset: 1.0744
# ==========================================================================================================================
# Epoch 37/300 - Train accuracy: 0.7927 - Train loss: 0.6048 - Validate accuracy: 0.6776 - Validate loss: 1.0744
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7339 - Count: 17
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5940 On 8000 - Accuracy: 0.7425
# Loss over whole dataset: 0.7920
# ==========================================================================================================================
# Epoch 38/300 - Train accuracy: 0.7947 - Train loss: 0.5966 - Validate accuracy: 0.7425 - Validate loss: 0.7920
# ==========================================================================================================================
# Number of batches:  63
# Correct: 5145 On 8000 - Accuracy: 0.6431
# Loss over whole dataset: 1.1289
# ==========================================================================================================================
# Epoch 39/300 - Train accuracy: 0.7977 - Train loss: 0.5914 - Validate accuracy: 0.6431 - Validate loss: 1.1289
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7425 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5612 On 8000 - Accuracy: 0.7015
# Loss over whole dataset: 0.9003
# ==========================================================================================================================
# Epoch 40/300 - Train accuracy: 0.7977 - Train loss: 0.5913 - Validate accuracy: 0.7015 - Validate loss: 0.9003
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7425 - Count: 2
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5823 On 8000 - Accuracy: 0.7279
# Loss over whole dataset: 0.8584
# ==========================================================================================================================
# Epoch 41/300 - Train accuracy: 0.7986 - Train loss: 0.5908 - Validate accuracy: 0.7279 - Validate loss: 0.8584
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7425 - Count: 3
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5990 On 8000 - Accuracy: 0.7488
# Loss over whole dataset: 0.7474
# ==========================================================================================================================
# Epoch 42/300 - Train accuracy: 0.7984 - Train loss: 0.5852 - Validate accuracy: 0.7488 - Validate loss: 0.7474
# ==========================================================================================================================
# Number of batches:  63
# Correct: 5096 On 8000 - Accuracy: 0.6370
# Loss over whole dataset: 1.1452
# ==========================================================================================================================
# Epoch 43/300 - Train accuracy: 0.7977 - Train loss: 0.5853 - Validate accuracy: 0.6370 - Validate loss: 1.1452
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7488 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5340 On 8000 - Accuracy: 0.6675
# Loss over whole dataset: 1.0803
# ==========================================================================================================================
# Epoch 44/300 - Train accuracy: 0.8005 - Train loss: 0.5836 - Validate accuracy: 0.6675 - Validate loss: 1.0803
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7488 - Count: 2
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6026 On 8000 - Accuracy: 0.7532
# Loss over whole dataset: 0.7110
# ==========================================================================================================================
# Epoch 45/300 - Train accuracy: 0.8015 - Train loss: 0.5773 - Validate accuracy: 0.7532 - Validate loss: 0.7110
# ==========================================================================================================================
# Number of batches:  63
# Correct: 5260 On 8000 - Accuracy: 0.6575
# Loss over whole dataset: 1.0525
# ==========================================================================================================================
# Epoch 46/300 - Train accuracy: 0.8017 - Train loss: 0.5772 - Validate accuracy: 0.6575 - Validate loss: 1.0525
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7532 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6074 On 8000 - Accuracy: 0.7592
# Loss over whole dataset: 0.7147
# ==========================================================================================================================
# Epoch 47/300 - Train accuracy: 0.7995 - Train loss: 0.5826 - Validate accuracy: 0.7592 - Validate loss: 0.7147
# ==========================================================================================================================
# Number of batches:  63
# Correct: 5468 On 8000 - Accuracy: 0.6835
# Loss over whole dataset: 0.9678
# ==========================================================================================================================
# Epoch 48/300 - Train accuracy: 0.7991 - Train loss: 0.5830 - Validate accuracy: 0.6835 - Validate loss: 0.9678
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7592 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 5900 On 8000 - Accuracy: 0.7375
# Loss over whole dataset: 0.7806
# ==========================================================================================================================
# Epoch 49/300 - Train accuracy: 0.8004 - Train loss: 0.5783 - Validate accuracy: 0.7375 - Validate loss: 0.7806
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.7592 - Count: 2
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6791 On 8000 - Accuracy: 0.8489
# Loss over whole dataset: 0.4442
# ==========================================================================================================================
# Epoch 50/300 - Train accuracy: 0.8610 - Train loss: 0.4053 - Validate accuracy: 0.8489 - Validate loss: 0.4442
# ==========================================================================================================================
# Number of batches:  63
# Correct: 6863 On 8000 - Accuracy: 0.8579
# Loss over whole dataset: 0.4200
# ==========================================================================================================================
# Epoch 51/300 - Train accuracy: 0.8779 - Train loss: 0.3560 - Validate accuracy: 0.8579 - Validate loss: 0.4200
# ==========================================================================================================================
# Number of batches:  63
# Correct: 6870 On 8000 - Accuracy: 0.8588
# Loss over whole dataset: 0.4074
# ==========================================================================================================================
# Epoch 52/300 - Train accuracy: 0.8840 - Train loss: 0.3402 - Validate accuracy: 0.8588 - Validate loss: 0.4074
# ==========================================================================================================================
# Number of batches:  63
# Correct: 6917 On 8000 - Accuracy: 0.8646
# Loss over whole dataset: 0.3970
# ==========================================================================================================================
# Epoch 53/300 - Train accuracy: 0.8919 - Train loss: 0.3176 - Validate accuracy: 0.8646 - Validate loss: 0.3970
# ==========================================================================================================================
# Number of batches:  63
# Correct: 6915 On 8000 - Accuracy: 0.8644
# Loss over whole dataset: 0.3919
# ==========================================================================================================================
# Epoch 54/300 - Train accuracy: 0.8934 - Train loss: 0.3071 - Validate accuracy: 0.8644 - Validate loss: 0.3919
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8646 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6952 On 8000 - Accuracy: 0.8690
# Loss over whole dataset: 0.3723
# ==========================================================================================================================
# Epoch 55/300 - Train accuracy: 0.8987 - Train loss: 0.2957 - Validate accuracy: 0.8690 - Validate loss: 0.3723
# ==========================================================================================================================
# Number of batches:  63
# Correct: 6989 On 8000 - Accuracy: 0.8736
# Loss over whole dataset: 0.3713
# ==========================================================================================================================
# Epoch 56/300 - Train accuracy: 0.8996 - Train loss: 0.2891 - Validate accuracy: 0.8736 - Validate loss: 0.3713
# ==========================================================================================================================
# Number of batches:  63
# Correct: 6961 On 8000 - Accuracy: 0.8701
# Loss over whole dataset: 0.3787
# ==========================================================================================================================
# Epoch 57/300 - Train accuracy: 0.9015 - Train loss: 0.2830 - Validate accuracy: 0.8701 - Validate loss: 0.3787
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8736 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6936 On 8000 - Accuracy: 0.8670
# Loss over whole dataset: 0.3813
# ==========================================================================================================================
# Epoch 58/300 - Train accuracy: 0.9058 - Train loss: 0.2704 - Validate accuracy: 0.8670 - Validate loss: 0.3813
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8736 - Count: 2
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6925 On 8000 - Accuracy: 0.8656
# Loss over whole dataset: 0.3853
# ==========================================================================================================================
# Epoch 59/300 - Train accuracy: 0.9038 - Train loss: 0.2735 - Validate accuracy: 0.8656 - Validate loss: 0.3853
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8736 - Count: 3
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6990 On 8000 - Accuracy: 0.8738
# Loss over whole dataset: 0.3711
# ==========================================================================================================================
# Epoch 60/300 - Train accuracy: 0.9092 - Train loss: 0.2640 - Validate accuracy: 0.8738 - Validate loss: 0.3711
# ==========================================================================================================================
# Number of batches:  63
# Correct: 6966 On 8000 - Accuracy: 0.8708
# Loss over whole dataset: 0.3788
# ==========================================================================================================================
# Epoch 61/300 - Train accuracy: 0.9106 - Train loss: 0.2591 - Validate accuracy: 0.8708 - Validate loss: 0.3788
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8738 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6982 On 8000 - Accuracy: 0.8728
# Loss over whole dataset: 0.3759
# ==========================================================================================================================
# Epoch 62/300 - Train accuracy: 0.9140 - Train loss: 0.2490 - Validate accuracy: 0.8728 - Validate loss: 0.3759
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8738 - Count: 2
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6969 On 8000 - Accuracy: 0.8711
# Loss over whole dataset: 0.3786
# ==========================================================================================================================
# Epoch 63/300 - Train accuracy: 0.9144 - Train loss: 0.2476 - Validate accuracy: 0.8711 - Validate loss: 0.3786
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8738 - Count: 3
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6999 On 8000 - Accuracy: 0.8749
# Loss over whole dataset: 0.3708
# ==========================================================================================================================
# Epoch 64/300 - Train accuracy: 0.9146 - Train loss: 0.2453 - Validate accuracy: 0.8749 - Validate loss: 0.3708
# ==========================================================================================================================
# Number of batches:  63
# Correct: 6996 On 8000 - Accuracy: 0.8745
# Loss over whole dataset: 0.3635
# ==========================================================================================================================
# Epoch 65/300 - Train accuracy: 0.9153 - Train loss: 0.2426 - Validate accuracy: 0.8745 - Validate loss: 0.3635
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8749 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6990 On 8000 - Accuracy: 0.8738
# Loss over whole dataset: 0.3846
# ==========================================================================================================================
# Epoch 66/300 - Train accuracy: 0.9169 - Train loss: 0.2398 - Validate accuracy: 0.8738 - Validate loss: 0.3846
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8749 - Count: 2
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6962 On 8000 - Accuracy: 0.8702
# Loss over whole dataset: 0.3892
# ==========================================================================================================================
# Epoch 67/300 - Train accuracy: 0.9178 - Train loss: 0.2370 - Validate accuracy: 0.8702 - Validate loss: 0.3892
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8749 - Count: 3
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6992 On 8000 - Accuracy: 0.8740
# Loss over whole dataset: 0.3745
# ==========================================================================================================================
# Epoch 68/300 - Train accuracy: 0.9205 - Train loss: 0.2320 - Validate accuracy: 0.8740 - Validate loss: 0.3745
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8749 - Count: 4
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6976 On 8000 - Accuracy: 0.8720
# Loss over whole dataset: 0.3854
# ==========================================================================================================================
# Epoch 69/300 - Train accuracy: 0.9207 - Train loss: 0.2278 - Validate accuracy: 0.8720 - Validate loss: 0.3854
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8749 - Count: 5
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7052 On 8000 - Accuracy: 0.8815
# Loss over whole dataset: 0.3635
# ==========================================================================================================================
# Epoch 70/300 - Train accuracy: 0.9218 - Train loss: 0.2235 - Validate accuracy: 0.8815 - Validate loss: 0.3635
# ==========================================================================================================================
# Number of batches:  63
# Correct: 6971 On 8000 - Accuracy: 0.8714
# Loss over whole dataset: 0.3840
# ==========================================================================================================================
# Epoch 71/300 - Train accuracy: 0.9221 - Train loss: 0.2213 - Validate accuracy: 0.8714 - Validate loss: 0.3840
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8815 - Count: 1
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6965 On 8000 - Accuracy: 0.8706
# Loss over whole dataset: 0.3840
# ==========================================================================================================================
# Epoch 72/300 - Train accuracy: 0.9228 - Train loss: 0.2236 - Validate accuracy: 0.8706 - Validate loss: 0.3840
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8815 - Count: 2
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7004 On 8000 - Accuracy: 0.8755
# Loss over whole dataset: 0.3755
# ==========================================================================================================================
# Epoch 73/300 - Train accuracy: 0.9230 - Train loss: 0.2203 - Validate accuracy: 0.8755 - Validate loss: 0.3755
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8815 - Count: 3
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6939 On 8000 - Accuracy: 0.8674
# Loss over whole dataset: 0.4148
# ==========================================================================================================================
# Epoch 74/300 - Train accuracy: 0.9239 - Train loss: 0.2188 - Validate accuracy: 0.8674 - Validate loss: 0.4148
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8815 - Count: 4
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6922 On 8000 - Accuracy: 0.8652
# Loss over whole dataset: 0.3924
# ==========================================================================================================================
# Epoch 75/300 - Train accuracy: 0.9265 - Train loss: 0.2155 - Validate accuracy: 0.8652 - Validate loss: 0.3924
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8815 - Count: 5
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6895 On 8000 - Accuracy: 0.8619
# Loss over whole dataset: 0.4102
# ==========================================================================================================================
# Epoch 76/300 - Train accuracy: 0.9267 - Train loss: 0.2144 - Validate accuracy: 0.8619 - Validate loss: 0.4102
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8815 - Count: 6
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7023 On 8000 - Accuracy: 0.8779
# Loss over whole dataset: 0.3667
# ==========================================================================================================================
# Epoch 77/300 - Train accuracy: 0.9260 - Train loss: 0.2071 - Validate accuracy: 0.8779 - Validate loss: 0.3667
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.8815 - Count: 7
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 6993 On 8000 - Accuracy: 0.8741
# ...
# Epoch 277/300 - Train accuracy: 0.9773 - Train loss: 0.0705 - Validate accuracy: 0.9002 - Validate loss: 0.3359
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 63
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7229 On 8000 - Accuracy: 0.9036
# Loss over whole dataset: 0.3287
# ==========================================================================================================================
# Epoch 278/300 - Train accuracy: 0.9764 - Train loss: 0.0715 - Validate accuracy: 0.9036 - Validate loss: 0.3287
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 64
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7193 On 8000 - Accuracy: 0.8991
# Loss over whole dataset: 0.3275
# ==========================================================================================================================
# Epoch 279/300 - Train accuracy: 0.9777 - Train loss: 0.0699 - Validate accuracy: 0.8991 - Validate loss: 0.3275
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 65
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7220 On 8000 - Accuracy: 0.9025
# Loss over whole dataset: 0.3118
# ==========================================================================================================================
# Epoch 280/300 - Train accuracy: 0.9760 - Train loss: 0.0723 - Validate accuracy: 0.9025 - Validate loss: 0.3118
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 66
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7205 On 8000 - Accuracy: 0.9006
# Loss over whole dataset: 0.3212
# ==========================================================================================================================
# Epoch 281/300 - Train accuracy: 0.9783 - Train loss: 0.0704 - Validate accuracy: 0.9006 - Validate loss: 0.3212
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 67
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7185 On 8000 - Accuracy: 0.8981
# Loss over whole dataset: 0.3268
# ==========================================================================================================================
# Epoch 282/300 - Train accuracy: 0.9765 - Train loss: 0.0711 - Validate accuracy: 0.8981 - Validate loss: 0.3268
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 68
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7187 On 8000 - Accuracy: 0.8984
# Loss over whole dataset: 0.3294
# ==========================================================================================================================
# Epoch 283/300 - Train accuracy: 0.9767 - Train loss: 0.0709 - Validate accuracy: 0.8984 - Validate loss: 0.3294
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 69
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7201 On 8000 - Accuracy: 0.9001
# Loss over whole dataset: 0.3291
# ==========================================================================================================================
# Epoch 284/300 - Train accuracy: 0.9769 - Train loss: 0.0719 - Validate accuracy: 0.9001 - Validate loss: 0.3291
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 70
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7201 On 8000 - Accuracy: 0.9001
# Loss over whole dataset: 0.3311
# ==========================================================================================================================
# Epoch 285/300 - Train accuracy: 0.9769 - Train loss: 0.0701 - Validate accuracy: 0.9001 - Validate loss: 0.3311
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 71
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7211 On 8000 - Accuracy: 0.9014
# Loss over whole dataset: 0.3302
# ==========================================================================================================================
# Epoch 286/300 - Train accuracy: 0.9773 - Train loss: 0.0701 - Validate accuracy: 0.9014 - Validate loss: 0.3302
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 72
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7204 On 8000 - Accuracy: 0.9005
# Loss over whole dataset: 0.3256
# ==========================================================================================================================
# Epoch 287/300 - Train accuracy: 0.9765 - Train loss: 0.0713 - Validate accuracy: 0.9005 - Validate loss: 0.3256
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 73
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7194 On 8000 - Accuracy: 0.8992
# Loss over whole dataset: 0.3295
# ==========================================================================================================================
# Epoch 288/300 - Train accuracy: 0.9778 - Train loss: 0.0688 - Validate accuracy: 0.8992 - Validate loss: 0.3295
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 74
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7169 On 8000 - Accuracy: 0.8961
# Loss over whole dataset: 0.3424
# ==========================================================================================================================
# Epoch 289/300 - Train accuracy: 0.9785 - Train loss: 0.0673 - Validate accuracy: 0.8961 - Validate loss: 0.3424
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 75
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7185 On 8000 - Accuracy: 0.8981
# Loss over whole dataset: 0.3264
# ==========================================================================================================================
# Epoch 290/300 - Train accuracy: 0.9769 - Train loss: 0.0707 - Validate accuracy: 0.8981 - Validate loss: 0.3264
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 76
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7221 On 8000 - Accuracy: 0.9026
# Loss over whole dataset: 0.3262
# ==========================================================================================================================
# Epoch 291/300 - Train accuracy: 0.9765 - Train loss: 0.0713 - Validate accuracy: 0.9026 - Validate loss: 0.3262
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 77
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7192 On 8000 - Accuracy: 0.8990
# Loss over whole dataset: 0.3207
# ==========================================================================================================================
# Epoch 292/300 - Train accuracy: 0.9777 - Train loss: 0.0683 - Validate accuracy: 0.8990 - Validate loss: 0.3207
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 78
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7190 On 8000 - Accuracy: 0.8988
# Loss over whole dataset: 0.3446
# ==========================================================================================================================
# Epoch 293/300 - Train accuracy: 0.9776 - Train loss: 0.0694 - Validate accuracy: 0.8988 - Validate loss: 0.3446
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 79
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7183 On 8000 - Accuracy: 0.8979
# Loss over whole dataset: 0.3379
# ==========================================================================================================================
# Epoch 294/300 - Train accuracy: 0.9766 - Train loss: 0.0722 - Validate accuracy: 0.8979 - Validate loss: 0.3379
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 80
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7214 On 8000 - Accuracy: 0.9018
# Loss over whole dataset: 0.3339
# ==========================================================================================================================
# Epoch 295/300 - Train accuracy: 0.9770 - Train loss: 0.0706 - Validate accuracy: 0.9018 - Validate loss: 0.3339
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 81
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7211 On 8000 - Accuracy: 0.9014
# Loss over whole dataset: 0.3245
# ==========================================================================================================================
# Epoch 296/300 - Train accuracy: 0.9767 - Train loss: 0.0715 - Validate accuracy: 0.9014 - Validate loss: 0.3245
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 82
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7187 On 8000 - Accuracy: 0.8984
# Loss over whole dataset: 0.3372
# ==========================================================================================================================
# Epoch 297/300 - Train accuracy: 0.9775 - Train loss: 0.0705 - Validate accuracy: 0.8984 - Validate loss: 0.3372
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 83
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7200 On 8000 - Accuracy: 0.9000
# Loss over whole dataset: 0.3335
# ==========================================================================================================================
# Epoch 298/300 - Train accuracy: 0.9775 - Train loss: 0.0694 - Validate accuracy: 0.9000 - Validate loss: 0.3335
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 84
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7196 On 8000 - Accuracy: 0.8995
# Loss over whole dataset: 0.3319
# ==========================================================================================================================
# Epoch 299/300 - Train accuracy: 0.9772 - Train loss: 0.0684 - Validate accuracy: 0.8995 - Validate loss: 0.3319
# ==========================================================================================================================
# ***************************************************************************
# Validation accuracy has not improved from: 0.9062 - Count: 85
# ***************************************************************************
# Early Stopping!
# Number of batches:  63
# Correct: 7255 On 8000 - Accuracy: 0.9069
# Loss over whole dataset: 0.3179
# ==========================================================================================================================
# Epoch 300/300 - Train accuracy: 0.9767 - Train loss: 0.0704 - Validate accuracy: 0.9069 - Validate loss: 0.3179
# ==========================================================================================================================

# %%
np.sum(epoch_times)/60
# Out:
# 103.56990678310395

# %%
calculate_loss_accuracy(network, validloader)

# %%
calculate_loss_accuracy(network, testloader)

# %%
trainset.data[1].shape

# %%
# loss = nn.CrossEntropyLoss()
# input = torch.randn(2, 2, requires_grad=True)
# target = torch.empty(2, dtype=torch.long).random_(2)
# output = loss(input, target)

# %%
# fig = plt.figure()
# for batch_idx, (data, target) in enumerate(trainloader):
#   if batch_idx %128 == 1:
#     for i in range(1,7):
#       ax = fig.add_subplot(2,3,i)
#       ax.imshow(torch.squeeze(data[i]).numpy())
#       ax.axis('off')
#       ax.set_title(target[i])

# %%
logs = pd.DataFrame({
    "Train_loss": np.array(train_losses),
    "Validate_loss": np.array(val_losses),
    "Train_accuracy": np.array(train_acces),
    "Validate_accuracy": np.array(val_acces),
    "Epoch_time": np.array(epoch_times),
    "Learning_rate": np.array(learning_rates)
    })

# %%
logs

# %%
logs['n_epoch'] = np.array([x for x in range(1, logs.shape[0]+1)])

# %%
logs

# %%
figure, (ax1, ax2) = plt.subplots(2, sharex=True, gridspec_kw = {'height_ratios':[3, 1]}, figsize=(20,10))
tr_loss = ax1.plot(logs['n_epoch'], logs['Train_loss'], label='Train_loss', color='red')
va_loss = ax1.plot(logs['n_epoch'], logs['Validate_loss'], label='Validate_loss', color='blue')
ax1.set_ylabel('Loss')
ax12 = ax1.twinx()
ax12.set_ylabel('Accuracy')
tr_acc = ax12.plot(logs['n_epoch'], logs['Train_accuracy'], label='Train_accuracy', color='green')
va_acc = ax12.plot(logs['n_epoch'], logs['Validate_accuracy'], label='Validate_accuracy', color='brown')
ax2.plot(logs['n_epoch'], logs['Learning_rate'])
ax2.set_ylabel('Learning rate')
leds = tr_loss + va_loss + tr_acc + va_acc
labs = [l.get_label() for l in leds]
figure.legend(leds, labs, loc="upper right")

# %%
logs.plot(x="n_epoch", y=["Train_loss","Validate_loss"], figsize=(20,10))

# %%
logs.plot(x="n_epoch", y=["Train_accuracy","Validate_accuracy"],figsize=(20,10))

# %%
logs.plot(x="n_epoch", y="Epoch_time", figsize=(20,10))

# %%
def confusion_matrix(net, dataloader):
  classes = dataloader.dataset.classes
  matrix = np.zeros((len(classes), len(classes)))

  device = torch.device('cuda' if torch.cuda.is_available else 'cpu')
  net = net.to(device)
  
  net.eval()
  with torch.no_grad():
    for _, (data, target) in enumerate(dataloader):
      data, target = data.to(device), target.to(device)
      output = net(data)
      preds = torch.argmax(output, dim=1)
      for idx, pred in enumerate(preds):
        actual = target[idx]
        matrix[pred, actual] += 1
  con_mat = pd.DataFrame(data=matrix, columns=classes, index=classes)
  for i, v in enumerate(classes):
    con_mat.loc[v,'total_predict'] = con_mat.loc[v,:].sum()
    con_mat.loc['total_actual',v] = con_mat.loc[:,v].sum()
  return con_mat.fillna(0).astype('int64')

# %%
c_m = confusion_matrix(network, testloader)

# %%
c_m

# %%
sns.heatmap(data=c_m.loc[trainset.classes, trainset.classes])

# %%
def stat_result(classes, confusion_matrix):
  columns = ['Class', 'Precision', 'Recall', 'F1_score']
  stat_matrix = pd.DataFrame(columns=columns, data=np.zeros((len(classes), len(columns))))
  for i, v in enumerate(classes):
    precision = confusion_matrix.iloc[i,i]/confusion_matrix.iloc[i, -1]
    recall    = confusion_matrix.iloc[i,i]/confusion_matrix.iloc[-1, i]
    stat_matrix.loc[i, 'Class'] = v
    stat_matrix.loc[i, 'Precision'] = precision
    stat_matrix.loc[i, 'Recall'] = recall
    stat_matrix.loc[i, 'F1_score'] = 2*precision*recall/(precision+recall)
  return stat_matrix

# %%
stat_table = stat_result(trainset.classes, c_m)

# %%
stat_table

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=pd.melt(stat_table, id_vars = 'Class', value_vars=['Precision', 'Recall', 'F1_score']), x='Class', y='value', hue='variable')

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=stat_table, x=stat_table.index, y='Recall')

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=stat_table, x=stat_table.index, y='Precision')

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=stat_table, x=stat_table.index, y='F1_score')

# %%
torch.cuda.empty_cache()

# %%
from torchsummary import summary

# %%
summary(network, (3,32,32))
